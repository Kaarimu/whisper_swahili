# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaarimu/whisper_swahili/blob/main/Gumzo_la_sato_ndoa_za_kuanikwa_mitandaonii.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 35.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 45.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 45.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 3.4 MB/s eta 0:00:00
# ...

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-d06f25f4-d50d-9536-5ca8-fde0d9ac1e3b)

# %%
# !pip install pytube -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.0 MB/s eta 0:00:00

# %%
import whisper
from pytube import YouTube

# %%
model = whisper.load_model('large-v2')
# Out:
# 100%|██████████████████████████████████████| 2.87G/2.87G [00:24<00:00, 126MiB/s]

# %%
youtube_video_url = "https://www.youtube.com/watch?v=Gt19ARdN9Qo"
youtube_video = YouTube(youtube_video_url)

# %%
youtube_video.title
# Out:
# 'Je, ndoa za  kuanikwa mitandaoni ni za kweli ama ni biashara? | Gumzo la Sato'

# %%
dir(youtube_video)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_age_restricted',
#  '_author',
#  '_embed_html',
#  '_fmt_streams',
#  '_initial_data',
#  '_js',
#  '_js_url',
#  '_metadata',
#  '_player_config_args',
#  '_publish_date',
#  '_title',
#  '_vid_info',
#  '_watch_html',
#  'age_restricted',
#  'allow_oauth_cache',
#  'author',
#  'bypass_age_gate',
#  'caption_tracks',
#  'captions',
#  'channel_id',
#  'channel_url',
#  'check_availability',
#  'description',
#  'embed_html',
#  'embed_url',
#  'fmt_streams',
#  'from_id',
#  'initial_data',
#  'js',
#  'js_url',
#  'keywords',
#  'length',
#  'metadata',
# ...

# %%
youtube_video.streams
# Out:
# [<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">, <Stream: itag="247" mime_type="video/webm" res="720p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">, <Stream: itag="244" mime_type="video/webm" res="480p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="243" mime_type="video/webm" res="360p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="1
# ...

# %%
for stream in youtube_video.streams:
  print(stream)
# Out:
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">
# <Stream: itag="247" mime_type="video/webm" res="720p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">
# <Stream: itag="244" mime_type="video/webm" res="480p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="243" mime_type="video/webm" res="360p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# ...

# %%
streams = youtube_video.streams.filter(only_audio=True)
streams
# Out:
# [<Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="249" mime_type="audio/webm" abr="50kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="250" mime_type="audio/webm" abr="70kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]

# %%
stream = streams.last()
stream
# Out:
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">

# %%
stream.download(filename='ndoa_za_kuanikwa_mitandaonii.mp4')
# Out:
# '/content/ndoa_za_kuanikwa_mitandaonii.mp4'

# %%
# do the transcription
import datetime

# save a timestamp before transcription
t1 = datetime.datetime.now()
print(f"started at {t1}")

# do the transcription
output = model.transcribe("ndoa_za_kuanikwa_mitandaonii.mp4")

# show time elapsed after transcription is complete.
t2 = datetime.datetime.now()
print(f"ended at {t2}")
print(f"time elapsed: {t2 - t1}")
# Out:
# started at 2024-04-07 18:36:45.602508
# ended at 2024-04-07 19:00:00.867700
# time elapsed: 0:23:15.265192

# %%
output
# Out:
# {'text': " Sitamu kama simfanyu mwinza ngu waezi ngutika tuki dogu Yani pachamangu nakuja nyumbani na kushutua tuki dogu Kumanisha kumba nakupenda Kitambo mahaba yalikwa tofauti lakini sasa mahaba yamebadilika Kwa hivyo mtuza mahajindani ya gumzo la sato jioni ya leo Tunangazia ndoa mza mitandaoni Ndoa za mitandaoni na soa yato kuhuliza je Hizi ndoa zinazwanikuwa mitandaoni nza kweli ama nikudanganyana Kutafutabia shara tuna wageni wetu jameni tuwafahamu wageni muje kwa moja usio Na mtuza mahaji tulio oliza na mkatambia jameni minawataka hawa wageni studio ni Na moja kwa moja kabisa tuko nao the Rui family Wakimbwezo jameni Kuyo ni buwana Hezron pamoja na Maureen Sitonik Hezron Kipkemoi Wapundani ya studio Hawa sasa uwa wakuna mbwenbu inyigi katika mitandaoni ya kijameni Na mtuza mahaji tulio uliza na mkatambia jameni Kutafutabia shara tutafutabia mbwenbu inyigi katika mitandaoni ya kijameni Mambo ni kuprankiana, mambo kudanganyana, mambo kudanganya wengine Wanasema jameni ndio mahab
# ...

# %%
output["text"]
# Out:
# " Sitamu kama simfanyu mwinza ngu waezi ngutika tuki dogu Yani pachamangu nakuja nyumbani na kushutua tuki dogu Kumanisha kumba nakupenda Kitambo mahaba yalikwa tofauti lakini sasa mahaba yamebadilika Kwa hivyo mtuza mahajindani ya gumzo la sato jioni ya leo Tunangazia ndoa mza mitandaoni Ndoa za mitandaoni na soa yato kuhuliza je Hizi ndoa zinazwanikuwa mitandaoni nza kweli ama nikudanganyana Kutafutabia shara tuna wageni wetu jameni tuwafahamu wageni muje kwa moja usio Na mtuza mahaji tulio oliza na mkatambia jameni minawataka hawa wageni studio ni Na moja kwa moja kabisa tuko nao the Rui family Wakimbwezo jameni Kuyo ni buwana Hezron pamoja na Maureen Sitonik Hezron Kipkemoi Wapundani ya studio Hawa sasa uwa wakuna mbwenbu inyigi katika mitandaoni ya kijameni Na mtuza mahaji tulio uliza na mkatambia jameni Kutafutabia shara tutafutabia mbwenbu inyigi katika mitandaoni ya kijameni Mambo ni kuprankiana, mambo kudanganyana, mambo kudanganya wengine Wanasema jameni ndio mahaba yawe ya
# ...

# %%
import pandas as pd

# %%
# The name of the file you want to save the output to
filename = 'ndoa_za_kuanikwa_mitandaonii.txt'

df = pd.DataFrame(output)
df.to_csv(filename)

# %%
for segment in output['segments']:
  print(segment)
  second = int(segment['start'])
  second = second - (second % 5)
  print(second)
# Out:
# {'id': 0, 'seek': 0, 'start': 0.0, 'end': 4.0, 'text': ' Sitamu kama simfanyu mwinza ngu waezi ngutika tuki dogu', 'tokens': [50364, 14523, 335, 84, 350, 2404, 1034, 69, 1325, 84, 275, 9136, 2394, 297, 2794, 5406, 68, 3992, 6415, 325, 5439, 2604, 2984, 360, 2794, 50564], 'temperature': 0.0, 'avg_logprob': -0.5095318114559954, 'compression_ratio': 1.7356828193832599, 'no_speech_prob': 0.212749183177948}
# 0
# {'id': 1, 'seek': 0, 'start': 4.0, 'end': 7.0, 'text': ' Yani pachamangu nakuja nyumbani na kushutua tuki dogu', 'tokens': [50564, 13633, 72, 280, 608, 335, 656, 84, 20332, 84, 2938, 18052, 2860, 3782, 1667, 350, 1498, 325, 4398, 2604, 2984, 360, 2794, 50714], 'temperature': 0.0, 'avg_logprob': -0.5095318114559954, 'compression_ratio': 1.7356828193832599, 'no_speech_prob': 0.212749183177948}
# 0
# ...

# %%
# !pip install googletrans
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 9.1 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15718 sha256=9494ac0c307414c624b8d73d3cf15c07eb6168460d07cc7aa34cad5182829c1f
#   Stored in directory: /root/.cache/pip/wheels/b3/81/ea/8b030407f8ebfc2f857814e086bb22ca2d4fea1a7be63652ab
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
from googletrans import Translator

# %%
# The text to translate
text = output["text"]

# %%
print(text)
length = len(text.split())
print(length)
# Out:
#  Sitamu kama simfanyu mwinza ngu waezi ngutika tuki dogu Yani pachamangu nakuja nyumbani na kushutua tuki dogu Kumanisha kumba nakupenda Kitambo mahaba yalikwa tofauti lakini sasa mahaba yamebadilika Kwa hivyo mtuza mahajindani ya gumzo la sato jioni ya leo Tunangazia ndoa mza mitandaoni Ndoa za mitandaoni na soa yato kuhuliza je Hizi ndoa zinazwanikuwa mitandaoni nza kweli ama nikudanganyana Kutafutabia shara tuna wageni wetu jameni tuwafahamu wageni muje kwa moja usio Na mtuza mahaji tulio oliza na mkatambia jameni minawataka hawa wageni studio ni Na moja kwa moja kabisa tuko nao the Rui family Wakimbwezo jameni Kuyo ni buwana Hezron pamoja na Maureen Sitonik Hezron Kipkemoi Wapundani ya studio Hawa sasa uwa wakuna mbwenbu inyigi katika mitandaoni ya kijameni Na mtuza mahaji tulio uliza na mkatambia jameni Kutafutabia shara tutafutabia mbwenbu inyigi katika mitandaoni ya kijameni Mambo ni kuprankiana, mambo kudanganyana, mambo kudanganya wengine Wanasema jameni ndio mahaba yawe ya 
# ...

# %%
# Create a translator object
translator = Translator()

# %%
# Translate the text
result_ndoa_za_kuanikwa_mitandaonii = translator.translate(text, src='sw', dest='en')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-17824c4fb448> in <cell line: 2>()
#       1 # Translate the text
# ----> 2 result_ndoa_za_kuanikwa_mitandaonii = translator.translate(text, src='sw', dest='en')
#
# /usr/local/lib/python3.10/dist-packages/googletrans/client.py in translate(self, text, dest, src, **kwargs)
#     180
#     181         origin = text
# --> 182         data = self._translate(text, dest, src, kwargs)
#     183
#     184         # this code will be updated when the format is changed.
#
# /usr/local/lib/python3.10/dist-packages/googletrans/client.py in _translate(self, text, dest, src, override)
#      76
#      77     def _translate(self, text, dest, src, override):
# ---> 78         token = self.token_acquirer.do(text)
#      79         params = utils.build_params(query=text, src=src, dest=dest,
# ...

# %%
# Print the translated text
print(result_heshima_mapenzi.text)

# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaarimu/whisper_swahili/blob/main/Kenyatta_bbb_speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git -q
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 71.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 107.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 23.6 MB/s eta 0:00:00
# ...

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-86fd2910-d42b-2f1a-fdae-bcb261ef0653)

# %%
# !pip install pytube -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 KB 5.3 MB/s eta 0:00:00

# %%
import whisper
from pytube import YouTube

# %%
model = whisper.load_model('large-v2')
# Out:
# 100%|██████████████████████████████████████| 2.87G/2.87G [00:27<00:00, 113MiB/s]

# %%
youtube_video_url = "https://www.youtube.com/watch?v=x6z37pb8N6g&t=12s"
youtube_video = YouTube(youtube_video_url)

# %%
youtube_video.title
# Out:
# 'Uhuru Kenyatta officially unveils the BBI Report |FULL SPEECH'

# %%
dir(youtube_video)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_age_restricted',
#  '_author',
#  '_embed_html',
#  '_fmt_streams',
#  '_initial_data',
#  '_js',
#  '_js_url',
#  '_metadata',
#  '_player_config_args',
#  '_publish_date',
#  '_title',
#  '_vid_info',
#  '_watch_html',
#  'age_restricted',
#  'allow_oauth_cache',
#  'author',
#  'bypass_age_gate',
#  'caption_tracks',
#  'captions',
#  'channel_id',
#  'channel_url',
#  'check_availability',
#  'description',
#  'embed_html',
#  'embed_url',
#  'fmt_streams',
#  'from_id',
#  'initial_data',
#  'js',
#  'js_url',
#  'keywords',
#  'length',
#  'metadata',
# ...

# %%
youtube_video.streams
# Out:
# [<Stream: itag="17" mime_type="video/3gpp" res="144p" fps="6fps" vcodec="mp4v.20.3" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="18" mime_type="video/mp4" res="360p" fps="25fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="135" mime_type="video/mp4" res="480p" fps="25fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="244" mime_type="video/webm" res="480p" fps="25fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="397" mime_type="video/mp4" res="480p" fps="25fps" vcodec="av01.0.04M.08.0.110.06.01.06.0" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="25fps" vcodec="avc1.4d4015" progressive="False" type="video">, <Stream: itag="243" mime_type="video/webm" res="360p" fps="25fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="396" mime_type="video/mp4" res="360p" fps="25fps" vcodec="av01.0.01M.08.0.110.06.01.06.0" progress
# ...

# %%
for stream in youtube_video.streams:
  print(stream)
# Out:
# <Stream: itag="17" mime_type="video/3gpp" res="144p" fps="6fps" vcodec="mp4v.20.3" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="25fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="135" mime_type="video/mp4" res="480p" fps="25fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="244" mime_type="video/webm" res="480p" fps="25fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="397" mime_type="video/mp4" res="480p" fps="25fps" vcodec="av01.0.04M.08.0.110.06.01.06.0" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="25fps" vcodec="avc1.4d4015" progressive="False" type="video">
# <Stream: itag="243" mime_type="video/webm" res="360p" fps="25fps" vcodec="vp9" progressive="False" type="video">
# ...

# %%
streams = youtube_video.streams.filter(only_audio=True)
streams
# Out:
# [<Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="249" mime_type="audio/webm" abr="50kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="250" mime_type="audio/webm" abr="70kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]

# %%
stream = streams.last()
stream
# Out:
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">

# %%
stream.download(filename='kenyatta_bbb_speech.mp4')
# Out:
# '/content/kenyatta_bbb_speech.mp4'

# %%
# do the transcription
import datetime

# save a timestamp before transcription
t1 = datetime.datetime.now()
print(f"started at {t1}")

# do the transcription
output = model.transcribe("kenyatta_bbb_speech.mp4")

# show time elapsed after transcription is complete.
t2 = datetime.datetime.now()
print(f"ended at {t2}")
print(f"time elapsed: {t2 - t1}")
# Out:
# started at 2023-01-15 04:45:28.956077
# ended at 2023-01-15 04:54:57.897455
# time elapsed: 0:09:28.941378

# %%
output
# Out:
# {'text': " Mbili! Wenzetu mbalozi yamba wa mehudhuri ya leo Na haswa mugeni wangu wa kipekee siku ya leo Waziri, wa inchi za inje, wa Tanzania, mdugu, kabundi yambayi minamuita kaguthi Wa Kenya wenzangu Siku ya leo ni siku muhimu Na vile ni mesema, siyo siku muhimu kwa angu mimi Lakini ni siku muhimu kwa wana inchi milioni arubaine na saba wa Kenya wazalendo Ambao, tuwajua katika kila kona ya taifaletu la Kenya leo Wanaangalia runinga, wehingine wago kwa maredio Na wote macho yao, fikra zao Ziko pa moja nasi katika kongo manolihi hapa BOMAS Na ni kwa nini? Ni kwa sababu Kila mkenya pa halipo pote halipo Anataka kusikia Mambwe yale ambao ya na jadiliwa hapa BOMAS Ambao tunaanzisha kujadili kama wa Kenya hapa BOMAS of Kenya Ni tabadilisha maisha yao ya kikawaida kwanji ya gani Na kwa hale wote ambao wameongea siku ya leo kwa maono yao na kwa kuunga mkono ya kuamba ya stahili Kwa kwenye wazalendo, wawena fasi ya kuongea pa moja Kuhusu tabu mbali mbali, shida mbali mbali Ambazo zinakumba
# ...

# %%
output["text"]
# Out:
# " Mbili! Wenzetu mbalozi yamba wa mehudhuri ya leo Na haswa mugeni wangu wa kipekee siku ya leo Waziri, wa inchi za inje, wa Tanzania, mdugu, kabundi yambayi minamuita kaguthi Wa Kenya wenzangu Siku ya leo ni siku muhimu Na vile ni mesema, siyo siku muhimu kwa angu mimi Lakini ni siku muhimu kwa wana inchi milioni arubaine na saba wa Kenya wazalendo Ambao, tuwajua katika kila kona ya taifaletu la Kenya leo Wanaangalia runinga, wehingine wago kwa maredio Na wote macho yao, fikra zao Ziko pa moja nasi katika kongo manolihi hapa BOMAS Na ni kwa nini? Ni kwa sababu Kila mkenya pa halipo pote halipo Anataka kusikia Mambwe yale ambao ya na jadiliwa hapa BOMAS Ambao tunaanzisha kujadili kama wa Kenya hapa BOMAS of Kenya Ni tabadilisha maisha yao ya kikawaida kwanji ya gani Na kwa hale wote ambao wameongea siku ya leo kwa maono yao na kwa kuunga mkono ya kuamba ya stahili Kwa kwenye wazalendo, wawena fasi ya kuongea pa moja Kuhusu tabu mbali mbali, shida mbali mbali Ambazo zinakumba maisha y
# ...

# %%
import pandas as pd

# %%
# The name of the file you want to save the output to
filename = 'kenyatta_bbb_speech.txt'

df = pd.DataFrame(output)
df.to_csv(filename)

# %%
for segment in output['segments']:
  print(segment)
  second = int(segment['start'])
  second = second - (second % 5)
  print(second)
# Out:
# {'id': 0, 'seek': 9000, 'start': 90.0, 'end': 94.0, 'text': ' Mbili!', 'tokens': [376, 65, 2312, 0], 'temperature': 0.2, 'avg_logprob': -0.720661481221517, 'compression_ratio': 1.1341463414634145, 'no_speech_prob': 0.4118947386741638}
# 90
# {'id': 1, 'seek': 9000, 'start': 94.0, 'end': 103.0, 'text': ' Wenzetu mbalozi yamba wa mehudhuri ya leo', 'tokens': [343, 11368, 41236, 275, 2645, 78, 3992, 288, 23337, 5406, 385, 71, 532, 71, 9744, 2478, 476, 78], 'temperature': 0.2, 'avg_logprob': -0.720661481221517, 'compression_ratio': 1.1341463414634145, 'no_speech_prob': 0.4118947386741638}
# 90
# {'id': 2, 'seek': 9000, 'start': 103.0, 'end': 112.0, 'text': ' Na haswa mugeni wangu wa kipekee siku ya leo', 'tokens': [6056, 575, 4151, 23610, 15711, 261, 656, 84, 5406, 350, 6527, 330, 68, 262, 24320, 2478, 476, 78], 'temperature': 0.2, 'avg_logprob': -0.720661481221517, 'compression_ratio': 1.1341463414634145, 'no_speech_prob': 0.4118947386741638}
# 100
# ...

# %%
# !pip install googletrans
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 KB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 60.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 KB 19.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 KB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 KB 10.0 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15735 sha256=6dc3bfc5e9f0aa4c38ebf4dead4e5eebd30960e248e477da93020df599cf5c03
#   Stored in directory: /root/.cache/pip/wheels/0e/ce/9b/d51de1064911d42480ab6b57fc943ee36572441f27546354e2
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
from googletrans import Translator

# %%
# The text to translate
text = output["text"]

# %%
print(text)
length = len(text.split())
print(length)
# Out:
#  Mbili! Wenzetu mbalozi yamba wa mehudhuri ya leo Na haswa mugeni wangu wa kipekee siku ya leo Waziri, wa inchi za inje, wa Tanzania, mdugu, kabundi yambayi minamuita kaguthi Wa Kenya wenzangu Siku ya leo ni siku muhimu Na vile ni mesema, siyo siku muhimu kwa angu mimi Lakini ni siku muhimu kwa wana inchi milioni arubaine na saba wa Kenya wazalendo Ambao, tuwajua katika kila kona ya taifaletu la Kenya leo Wanaangalia runinga, wehingine wago kwa maredio Na wote macho yao, fikra zao Ziko pa moja nasi katika kongo manolihi hapa BOMAS Na ni kwa nini? Ni kwa sababu Kila mkenya pa halipo pote halipo Anataka kusikia Mambwe yale ambao ya na jadiliwa hapa BOMAS Ambao tunaanzisha kujadili kama wa Kenya hapa BOMAS of Kenya Ni tabadilisha maisha yao ya kikawaida kwanji ya gani Na kwa hale wote ambao wameongea siku ya leo kwa maono yao na kwa kuunga mkono ya kuamba ya stahili Kwa kwenye wazalendo, wawena fasi ya kuongea pa moja Kuhusu tabu mbali mbali, shida mbali mbali Ambazo zinakumba maisha ya
# ...

# %%
# Create a translator object
translator = Translator()

# %%
# Translate the text
result_kenyatta_bbb_speech = translator.translate(text, src='sw', dest='en')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-c36f57e1a07f> in <module>
#       1 # Translate the text
# ----> 2 result_kenyatta_bbb_speech = translator.translate(text, src='sw', dest='en')
#
# /usr/local/lib/python3.8/dist-packages/googletrans/client.py in translate(self, text, dest, src, **kwargs)
#     180
#     181         origin = text
# --> 182         data = self._translate(text, dest, src, kwargs)
#     183
#     184         # this code will be updated when the format is changed.
#
# /usr/local/lib/python3.8/dist-packages/googletrans/client.py in _translate(self, text, dest, src, override)
#      76
#      77     def _translate(self, text, dest, src, override):
# ---> 78         token = self.token_acquirer.do(text)
#      79         params = utils.build_params(query=text, src=src, dest=dest,
# ...

# %%
# Print the translated text
print(result_kenyatta_bbb_speech.text)

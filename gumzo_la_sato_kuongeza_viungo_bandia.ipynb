# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaarimu/whisper_swahili/blob/main/gumzo_la_sato_kuongeza_viungo_bandia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git -q
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 81.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 103.2 MB/s eta 0:00:00
# ...

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-e2b2750a-61f3-4e5f-94c4-513dba4dd518)

# %%
# !pip install pytube -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 KB 3.8 MB/s eta 0:00:00

# %%
import whisper
from pytube import YouTube

# %%
model = whisper.load_model('large-v2')
# Out:
# 100%|█████████████████████████████████████| 2.87G/2.87G [00:48<00:00, 63.6MiB/s]

# %%
youtube_video_url = "https://www.youtube.com/watch?v=yd8amsMsBT8"
youtube_video = YouTube(youtube_video_url)

# %%
youtube_video.title
# Out:
# 'Je, kuongeza urembo na sehemu za mwili bandia ni ulaghai wa kimapenzi? | Gumzo la Sato'

# %%
dir(youtube_video)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_age_restricted',
#  '_author',
#  '_embed_html',
#  '_fmt_streams',
#  '_initial_data',
#  '_js',
#  '_js_url',
#  '_metadata',
#  '_player_config_args',
#  '_publish_date',
#  '_title',
#  '_vid_info',
#  '_watch_html',
#  'age_restricted',
#  'allow_oauth_cache',
#  'author',
#  'bypass_age_gate',
#  'caption_tracks',
#  'captions',
#  'channel_id',
#  'channel_url',
#  'check_availability',
#  'description',
#  'embed_html',
#  'embed_url',
#  'fmt_streams',
#  'from_id',
#  'initial_data',
#  'js',
#  'js_url',
#  'keywords',
#  'length',
#  'metadata',
# ...

# %%
youtube_video.streams
# Out:
# [<Stream: itag="17" mime_type="video/3gpp" res="144p" fps="8fps" vcodec="mp4v.20.3" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">, <Stream: itag="247" mime_type="video/webm" res="720p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">, <Stream: itag="244" mime_type="video/webm" res="480p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="vid
# ...

# %%
for stream in youtube_video.streams:
  print(stream)
# Out:
# <Stream: itag="17" mime_type="video/3gpp" res="144p" fps="8fps" vcodec="mp4v.20.3" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">
# <Stream: itag="247" mime_type="video/webm" res="720p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">
# <Stream: itag="244" mime_type="video/webm" res="480p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# ...

# %%
streams = youtube_video.streams.filter(only_audio=True)
streams
# Out:
# [<Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="249" mime_type="audio/webm" abr="50kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="250" mime_type="audio/webm" abr="70kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]

# %%
stream = streams.last()
stream
# Out:
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">

# %%
stream.download(filename='gumzo_la_sato_kuongeza_viungo_bandia.mp4')
# Out:
# '/content/gumzo_la_sato_kuongeza_viungo_bandia.mp4'

# %%
# do the transcription
import datetime

# save a timestamp before transcription
t1 = datetime.datetime.now()
print(f"started at {t1}")

# do the transcription
output = model.transcribe("gumzo_la_sato_kuongeza_viungo_bandia.mp4")

# show time elapsed after transcription is complete.
t2 = datetime.datetime.now()
print(f"ended at {t2}")
print(f"time elapsed: {t2 - t1}")
# Out:
# started at 2023-01-15 05:49:41.568181
# ended at 2023-01-15 06:14:29.205292
# time elapsed: 0:24:47.637111

# %%
output
# Out:
# {'text': " Huzza na kengele fida. Hujambo? Hey, njamani. Leo nasumaje. One letter wapi apa? Ha ha, siki ya. Watakau Futwa machozi na mi Nime chaguliwa Ha ha Hey Komuda murefo Ha, me kisikia Hibnina Kili yo Charles chana kimesikika Nao Waibu, pia nao wako katika wale wa te ule amba wa mechaguliwa Iwe unavyo, iwe huna, umechaguliwa Waaswaili wanasema Zigu la kuliwa, halilemei Yani kama zigu unalitaka Hata kama zito, wananlakula Utalibe bahari nyumbani Leo nasugumzia hi ho Ha ho Ha ho He he Kwa manisha nini fida? Hahahaha Mtuzamaji njamani Wanoma mijitokeza katika mtelo ya kijami Kila mahali wanasema kwa basisi Wanawake, tuna watapedi Kwa ni katika ground Wanakutana namuana mkiamba ya kuhivi Hamejaja Lakini wafika po nyumbani Inakua mambo nitofau Nyandi yo mana leo katika gumzo la sato Tutaka tu saidiye boychild Jamiini tuangalie Iwapo kuungeza makalio Kuungeza vigo doro Mapambo kupita kiasi Kupunguza tumbo kwa kunyomyo Na kadhalika ye unutapeli wa kimapezi, Frida Ebuni kulize lofti Sas
# ...

# %%
output["text"]
# Out:
# " Huzza na kengele fida. Hujambo? Hey, njamani. Leo nasumaje. One letter wapi apa? Ha ha, siki ya. Watakau Futwa machozi na mi Nime chaguliwa Ha ha Hey Komuda murefo Ha, me kisikia Hibnina Kili yo Charles chana kimesikika Nao Waibu, pia nao wako katika wale wa te ule amba wa mechaguliwa Iwe unavyo, iwe huna, umechaguliwa Waaswaili wanasema Zigu la kuliwa, halilemei Yani kama zigu unalitaka Hata kama zito, wananlakula Utalibe bahari nyumbani Leo nasugumzia hi ho Ha ho Ha ho He he Kwa manisha nini fida? Hahahaha Mtuzamaji njamani Wanoma mijitokeza katika mtelo ya kijami Kila mahali wanasema kwa basisi Wanawake, tuna watapedi Kwa ni katika ground Wanakutana namuana mkiamba ya kuhivi Hamejaja Lakini wafika po nyumbani Inakua mambo nitofau Nyandi yo mana leo katika gumzo la sato Tutaka tu saidiye boychild Jamiini tuangalie Iwapo kuungeza makalio Kuungeza vigo doro Mapambo kupita kiasi Kupunguza tumbo kwa kunyomyo Na kadhalika ye unutapeli wa kimapezi, Frida Ebuni kulize lofti Sasa weu kit
# ...

# %%
import pandas as pd

# %%
# The name of the file you want to save the output to
filename = 'gumzo_la_sato_kuongeza_viungo_bandia.txt'

df = pd.DataFrame(output)
df.to_csv(filename)

# %%
for segment in output['segments']:
  print(segment)
  second = int(segment['start'])
  second = second - (second % 5)
  print(second)
# Out:
# {'id': 0, 'seek': 0, 'start': 0.0, 'end': 1.6400000000000001, 'text': ' Huzza na kengele fida.', 'tokens': [389, 3334, 2394, 1667, 350, 3032, 306, 283, 2887, 13], 'temperature': 0.2, 'avg_logprob': -0.7669015222666214, 'compression_ratio': 1.540084388185654, 'no_speech_prob': 0.22529634833335876}
# 0
# {'id': 1, 'seek': 0, 'start': 1.6400000000000001, 'end': 2.14, 'text': ' Hujambo?', 'tokens': [389, 4579, 335, 1763, 30], 'temperature': 0.2, 'avg_logprob': -0.7669015222666214, 'compression_ratio': 1.540084388185654, 'no_speech_prob': 0.22529634833335876}
# 0
# {'id': 2, 'seek': 0, 'start': 2.14, 'end': 3.38, 'text': ' Hey, njamani.', 'tokens': [1911, 11, 297, 73, 6147, 72, 13], 'temperature': 0.2, 'avg_logprob': -0.7669015222666214, 'compression_ratio': 1.540084388185654, 'no_speech_prob': 0.22529634833335876}
# 0
# ...

# %%
# !pip install googletrans
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 KB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 KB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 70.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 KB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 KB 8.3 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15735 sha256=f9a4190a4bdd968728edb637500fdb37703c5962cee44112f7a0f6fae382c3f8
#   Stored in directory: /root/.cache/pip/wheels/0e/ce/9b/d51de1064911d42480ab6b57fc943ee36572441f27546354e2
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
from googletrans import Translator

# %%
# The text to translate
text = output["text"]

# %%
print(text)
length = len(text.split())
print(length)
# Out:
#  Huzza na kengele fida. Hujambo? Hey, njamani. Leo nasumaje. One letter wapi apa? Ha ha, siki ya. Watakau Futwa machozi na mi Nime chaguliwa Ha ha Hey Komuda murefo Ha, me kisikia Hibnina Kili yo Charles chana kimesikika Nao Waibu, pia nao wako katika wale wa te ule amba wa mechaguliwa Iwe unavyo, iwe huna, umechaguliwa Waaswaili wanasema Zigu la kuliwa, halilemei Yani kama zigu unalitaka Hata kama zito, wananlakula Utalibe bahari nyumbani Leo nasugumzia hi ho Ha ho Ha ho He he Kwa manisha nini fida? Hahahaha Mtuzamaji njamani Wanoma mijitokeza katika mtelo ya kijami Kila mahali wanasema kwa basisi Wanawake, tuna watapedi Kwa ni katika ground Wanakutana namuana mkiamba ya kuhivi Hamejaja Lakini wafika po nyumbani Inakua mambo nitofau Nyandi yo mana leo katika gumzo la sato Tutaka tu saidiye boychild Jamiini tuangalie Iwapo kuungeza makalio Kuungeza vigo doro Mapambo kupita kiasi Kupunguza tumbo kwa kunyomyo Na kadhalika ye unutapeli wa kimapezi, Frida Ebuni kulize lofti Sasa weu kite
# ...

# %%
# Create a translator object
translator = Translator()

# %%
# Translate the text
result_gumzo_la_sato_kuongeza_viungo_bandia = translator.translate(text, src='sw', dest='en')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-bf13aaa544a6> in <module>
#       1 # Translate the text
# ----> 2 result_gumzo_la_sato_kuongeza_viungo_bandia = translator.translate(text, src='sw', dest='en')
#
# /usr/local/lib/python3.8/dist-packages/googletrans/client.py in translate(self, text, dest, src, **kwargs)
#     180
#     181         origin = text
# --> 182         data = self._translate(text, dest, src, kwargs)
#     183
#     184         # this code will be updated when the format is changed.
#
# /usr/local/lib/python3.8/dist-packages/googletrans/client.py in _translate(self, text, dest, src, override)
#      76
#      77     def _translate(self, text, dest, src, override):
# ---> 78         token = self.token_acquirer.do(text)
#      79         params = utils.build_params(query=text, src=src, dest=dest,
# ...

# %%
# Print the translated text
print(result_gumzo_la_sato_kuongeza_viungo_bandia.text)

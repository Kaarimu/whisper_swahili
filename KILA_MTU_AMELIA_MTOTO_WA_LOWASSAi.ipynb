# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaarimu/whisper_swahili/blob/main/KILA_MTU_AMELIA_MTOTO_WA_LOWASSAi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.8 MB/s eta 0:00:00
# ...

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-6f3edfb8-18e3-0939-8a65-d5d58bc5ddce)

# %%
# !pip install pytube -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 937.7 kB/s eta 0:00:00

# %%
import whisper
from pytube import YouTube

# %%
model = whisper.load_model('large-v2')
# Out:
# 100%|█████████████████████████████████████| 2.87G/2.87G [01:10<00:00, 44.0MiB/s]

# %%
youtube_video_url = "https://www.youtube.com/watch?v=vr1Z0DMXBo4"
youtube_video = YouTube(youtube_video_url)

# %%
youtube_video.title
# Out:
# 'KILA MTU AMELIA MTOTO WA LOWASSA AKIELEZA SIKU YA KIFO CHA BABA YAKE KUMBE ALI..'

# %%
dir(youtube_video)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_age_restricted',
#  '_author',
#  '_embed_html',
#  '_fmt_streams',
#  '_initial_data',
#  '_js',
#  '_js_url',
#  '_metadata',
#  '_player_config_args',
#  '_publish_date',
#  '_title',
#  '_vid_info',
#  '_watch_html',
#  'age_restricted',
#  'allow_oauth_cache',
#  'author',
#  'bypass_age_gate',
#  'caption_tracks',
#  'captions',
#  'channel_id',
#  'channel_url',
#  'check_availability',
#  'description',
#  'embed_html',
#  'embed_url',
#  'fmt_streams',
#  'from_id',
#  'initial_data',
#  'js',
#  'js_url',
#  'keywords',
#  'length',
#  'metadata',
# ...

# %%
youtube_video.streams
# Out:
# [<Stream: itag="18" mime_type="video/mp4" res="360p" fps="20fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="22" mime_type="video/mp4" res="720p" fps="20fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="20fps" vcodec="avc1.4d401f" progressive="False" type="video">, <Stream: itag="247" mime_type="video/webm" res="720p" fps="20fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="135" mime_type="video/mp4" res="480p" fps="20fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="244" mime_type="video/webm" res="480p" fps="20fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="20fps" vcodec="avc1.4d4016" progressive="False" type="video">, <Stream: itag="243" mime_type="video/webm" res="360p" fps="20fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="1
# ...

# %%
for stream in youtube_video.streams:
  print(stream)
# Out:
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="20fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="22" mime_type="video/mp4" res="720p" fps="20fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="20fps" vcodec="avc1.4d401f" progressive="False" type="video">
# <Stream: itag="247" mime_type="video/webm" res="720p" fps="20fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="135" mime_type="video/mp4" res="480p" fps="20fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="244" mime_type="video/webm" res="480p" fps="20fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="20fps" vcodec="avc1.4d4016" progressive="False" type="video">
# <Stream: itag="243" mime_type="video/webm" res="360p" fps="20fps" vcodec="vp9" progressive="False" type="video">
# ...

# %%
streams = youtube_video.streams.filter(only_audio=True)
streams
# Out:
# [<Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="249" mime_type="audio/webm" abr="50kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="250" mime_type="audio/webm" abr="70kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]

# %%
stream = streams.last()
stream
# Out:
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">

# %%
stream.download(filename='KILA_MTU_AMELIA_MTOTO_WA_LOWASSAi.mp4')
# Out:
# '/content/KILA_MTU_AMELIA_MTOTO_WA_LOWASSAi.mp4'

# %%
# do the transcription
import datetime

# save a timestamp before transcription
t1 = datetime.datetime.now()
print(f"started at {t1}")

# do the transcription
output = model.transcribe("KILA_MTU_AMELIA_MTOTO_WA_LOWASSAi.mp4")

# show time elapsed after transcription is complete.
t2 = datetime.datetime.now()
print(f"ended at {t2}")
print(f"time elapsed: {t2 - t1}")
# Out:
# started at 2023-01-15 03:08:16.801901
# ended at 2023-01-15 03:21:36.268718
# time elapsed: 0:13:19.466817

# %%
output
# Out:
# {'text': " KLchenki! Kwa hivyo kwa kanga, kwa kanga shanga, kwa panguwa, kwa penzi huyenga, kwa penzi mwomo, kwa penzi ajira hutoa, kwa penzi hufuta mtu kazi, kwa penzi hepenzi, kwa penzi inini? Na, hii leo tuja dili mpenzi kazini. Mtazamaji suali mtanda honi tuwa kuuliza je, kuna shida kufanya kazi na mpenzi yo, mkeo, mwomeo, kazini, je. Kuna shida afisi moja wewe na mkeo, mpenzi yo, mkeo, mwomeo, ufanye kazi pamoja. Zungumze na si at loft matambo at NTV Kenya, alami hareli kwenye gumzula sa top, wakini wetu tari wa meje aja studio onim. Tuko na KMO, muimbaji wa titima, doa miimba kibwa uhiki, washa-washa, pamoje na mkewe, pika na rage, wote ni wana mitandao. Wote wanafanya mauzu mitandao onim, wana shooti video usiku kucha mcha na kutua, sibi ibo si nani, aliandikuwa kazi nani, watasema wenyewe. Lakini kazi undhundi pia ni mshauri wetu kama kawaida, yuko studio onim. Karibu kwenye gumzula sa top, mieni wako loft matambo, pachawangu leo ni mpenzi mtazamaji. Karibu. Kazi wangu watu n
# ...

# %%
output["text"]
# Out:
# " KLchenki! Kwa hivyo kwa kanga, kwa kanga shanga, kwa panguwa, kwa penzi huyenga, kwa penzi mwomo, kwa penzi ajira hutoa, kwa penzi hufuta mtu kazi, kwa penzi hepenzi, kwa penzi inini? Na, hii leo tuja dili mpenzi kazini. Mtazamaji suali mtanda honi tuwa kuuliza je, kuna shida kufanya kazi na mpenzi yo, mkeo, mwomeo, kazini, je. Kuna shida afisi moja wewe na mkeo, mpenzi yo, mkeo, mwomeo, ufanye kazi pamoja. Zungumze na si at loft matambo at NTV Kenya, alami hareli kwenye gumzula sa top, wakini wetu tari wa meje aja studio onim. Tuko na KMO, muimbaji wa titima, doa miimba kibwa uhiki, washa-washa, pamoje na mkewe, pika na rage, wote ni wana mitandao. Wote wanafanya mauzu mitandao onim, wana shooti video usiku kucha mcha na kutua, sibi ibo si nani, aliandikuwa kazi nani, watasema wenyewe. Lakini kazi undhundi pia ni mshauri wetu kama kawaida, yuko studio onim. Karibu kwenye gumzula sa top, mieni wako loft matambo, pachawangu leo ni mpenzi mtazamaji. Karibu. Kazi wangu watu nasimu ata
# ...

# %%
import pandas as pd

# %%
# The name of the file you want to save the output to
filename = 'gumzo_la_sato_mapenzi_kazini.txt'

df = pd.DataFrame(output)
df.to_csv(filename)

# %%
for segment in output['segments']:
  print(segment)
  second = int(segment['start'])
  second = second - (second % 5)
  print(second)
# Out:
# {'id': 0, 'seek': 0, 'start': 0.0, 'end': 12.24, 'text': ' KLchenki!', 'tokens': [50364, 47991, 2470, 2984, 0, 50976], 'temperature': 1.0, 'avg_logprob': -5.574529920305524, 'compression_ratio': 0.5294117647058824, 'no_speech_prob': 0.42108282446861267}
# 0
# ...

# %%
# !pip install googletrans
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 KB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 70.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 KB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 KB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 KB 8.1 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15735 sha256=478050833c17238cff93db850940e4bd6f6375813ac409a6a3aa80f8b6b256ca
#   Stored in directory: /root/.cache/pip/wheels/0e/ce/9b/d51de1064911d42480ab6b57fc943ee36572441f27546354e2
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
from googletrans import Translator

# %%
# The text to translate
text = output["text"]

# %%
print(text)
length = len(text.split())
print(length)
# Out:
#  KLchenki! Kwa hivyo kwa kanga, kwa kanga shanga, kwa panguwa, kwa penzi huyenga, kwa penzi mwomo, kwa penzi ajira hutoa, kwa penzi hufuta mtu kazi, kwa penzi hepenzi, kwa penzi inini? Na, hii leo tuja dili mpenzi kazini. Mtazamaji suali mtanda honi tuwa kuuliza je, kuna shida kufanya kazi na mpenzi yo, mkeo, mwomeo, kazini, je. Kuna shida afisi moja wewe na mkeo, mpenzi yo, mkeo, mwomeo, ufanye kazi pamoja. Zungumze na si at loft matambo at NTV Kenya, alami hareli kwenye gumzula sa top, wakini wetu tari wa meje aja studio onim. Tuko na KMO, muimbaji wa titima, doa miimba kibwa uhiki, washa-washa, pamoje na mkewe, pika na rage, wote ni wana mitandao. Wote wanafanya mauzu mitandao onim, wana shooti video usiku kucha mcha na kutua, sibi ibo si nani, aliandikuwa kazi nani, watasema wenyewe. Lakini kazi undhundi pia ni mshauri wetu kama kawaida, yuko studio onim. Karibu kwenye gumzula sa top, mieni wako loft matambo, pachawangu leo ni mpenzi mtazamaji. Karibu. Kazi wangu watu nasimu atak
# ...

# %%
# Create a translator object
translator = Translator()

# %%
# Translate the text
result_heshima_mapenzi = translator.translate(text, src='sw', dest='en')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-318b93196a1c> in <module>
#       1 # Translate the text
# ----> 2 result_heshima_mapenzi = translator.translate(text, src='sw', dest='en')
#
# /usr/local/lib/python3.8/dist-packages/googletrans/client.py in translate(self, text, dest, src, **kwargs)
#     180
#     181         origin = text
# --> 182         data = self._translate(text, dest, src, kwargs)
#     183
#     184         # this code will be updated when the format is changed.
#
# /usr/local/lib/python3.8/dist-packages/googletrans/client.py in _translate(self, text, dest, src, override)
#      76
#      77     def _translate(self, text, dest, src, override):
# ---> 78         token = self.token_acquirer.do(text)
#      79         params = utils.build_params(query=text, src=src, dest=dest,
# ...

# %%
# Print the translated text
print(result_heshima_mapenzi.text)
